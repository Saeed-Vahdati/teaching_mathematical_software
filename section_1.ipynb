# %%
print('Hello')
# Out:
# Hello

# %%
type(2.3)
# Out:
# float

# %%
type(2.)
# Out:
# float

# %%
type('salam')
# Out:
# str

# %%
type('243')
# Out:
# str

# %%
int(-2.3)
# Out:
# -2

# %%
int(float('2.35'))
# Out:
# 2

# %%
int('2.35')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6533fe078f95> in <cell line: 1>()
# ----> 1 int('2.35')
#
# ValueError: invalid literal for int() with base 10: '2.35'

# %%
5 + 5
# Out:
# 10

# %%
8 - 19
# Out:
# -11

# %%
5 * 5
# Out:
# 25

# %%
2 ** 5
# Out:
# 32

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %%
3 ** (3/8)
# Out:
# 1.509803648477105

# %%
 25 % 3
# Out:
# 1

# %%
2016 % 28
# Out:
# 0

# %%
25 // 3
# Out:
# 8

# %%
2016 // 28
# Out:
# 72
