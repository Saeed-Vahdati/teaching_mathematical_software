# %% [markdown]
# $\int_{10}^{20}\frac{1+ x^2 + \sin(x)}{\ln x -\tanh(x)}dx$
#  $$\sum_{n=0}^{\infty}\frac{\alpha}{n^2+1}$$
#  $$\theta \in \mathbb{R}^n $$

# %% [markdown]
# $$\frac{\sqrt{1+\sqrt{12}}}{\sqrt[3]{1-\sqrt{7}}}$$

# %%
 a = 1 + 12 ** 0.5
 b = a ** 0.5
 c = 1 - 7 ** 0.5
 d = c ** (1/3)

# %%
b / d
# Out:
# (0.894778699395778-1.5498021688838866j)

# %%
(1 + 12 ** 0.5) ** 0.5 / (1 - 7 ** 0.5) ** (1 / 3)
# Out:
# (0.894778699395778-1.5498021688838866j)
